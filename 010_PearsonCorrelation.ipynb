# %% [markdown]
# # Data Dictionary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.datasets import make_regression
# Out:
# c:\python38\lib\site-packages\sklearn\experimental\enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
from scipy import stats
from datetime import datetime
from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('csv_data/all_lqt2_data_trunc(herg_combined_data).csv')

# %%
list(data)
# Out:
# ['Unnamed: 0',
#  'var',
#  'isoform',
#  'mut_type',
#  'resnum',
#  'lqt2',
#  'unaff',
#  'total_carriers',
#  'gnomAD',
#  'gnomAD_seq',
#  'weight',
#  'penetrance_lqt2',
#  'lqt2_penetranceBayesian_initial',
#  'lqt2_penetranceBayesian',
#  'pph2_prob',
#  'blast_pssm',
#  'provean_score',
#  'pamscore',
#  'aasimilaritymat',
#  'revel_score',
#  'hm_ssPeak',
#  'hm_tailPeak',
#  'hm_vhalfact',
#  'hm_vhalfinact',
#  'hm_recovfrominact',
#  'hm_taudeact_fast',
#  'ht_ssPeak',
#  'ht_tailPeak',
#  'ht_vhalfact',
#  'ht_vhalfinact',
#  'ht_recovfrominact',
#  'ht_taudeact_fast',
#  'lqt2_dist',
#  'lqt2_dist_weight',
#  'Structure',
#  'Function',
#  'p_mean_w',
#  'prior_mean_w',
#  'prior_mean',
#  'alpha',
#  'beta',
#  'lqt2_patho',
#  'p_mean_prior',
#  'RMSF',
#  'lqt2_dist_sequence',
#  'lqt2_dist_weight_sequence',
#  'lqt2_dist_observed',
#  'lqt2_dist_weight_observed',
#  'lqt2_dist_max',
#  'lqt2_dist_weight_max',
#  'lqt2_dist_mean',
#  'lqt2_dist_weight_mean',
#  'lqt2_dist_obs_max',
#  'lqt2_dist_weight_obs_max',
#  'lqt2_dist_obs_mean',
#  'lqt2_dist_weight_obs_mean',
#  'lqt2_dist_obs_seq',
#  'lqt2_dist_weight_obs_seq']

# %%
filter_columns = ['penetrance_lqt2','RMSF','lqt2_dist_sequence','lqt2_dist_weight_sequence',
                  'lqt2_dist_observed','lqt2_dist_weight_observed', 'lqt2_dist_max', 
                  'lqt2_dist_weight_max','lqt2_dist_mean','lqt2_dist_weight_mean',
                  'lqt2_dist_obs_max','lqt2_dist_weight_obs_max','lqt2_dist_obs_mean',
                  'lqt2_dist_weight_obs_mean','lqt2_dist_obs_seq','lqt2_dist_weight_obs_seq']

# %%
df = data.filter(filter_columns, axis=1)

# %%
df
# Out:
#      penetrance_lqt2      RMSF  lqt2_dist_sequence  lqt2_dist_weight_sequence  \
# 0                0.0       NaN            0.000950                   1.402061
# 1                0.0       NaN            0.000950                   1.402061
# 2                0.0       NaN            0.000950                   1.402061
# 3                0.0       NaN            0.011691                   1.086629
# 4                0.0       NaN            0.011691                   1.086629
# ..               ...       ...                 ...                        ...
# 895              1.0  0.679127            0.891571                   0.912280
# 896              1.0  0.808163            0.816971                   1.075925
# 897              0.0       NaN            0.480663                   0.109546
# 898              1.0  0.882337            0.847661                   1.243046
# 899              1.0  0.882337            0.847661                   1.243046
#
#      lqt2_dist_observed  lqt2_dist_weight_observed  lqt2_dist_max  \
# 0                   NaN                        NaN       0.000950
# 1                   NaN                        NaN       0.000950
# 2                   NaN                        NaN       0.000950
# 3                   NaN                        NaN       0.011691
# 4                   NaN                        NaN       0.011691
# ..                  ...                        ...            ...
# 895            0.848384                   1.428122       0.787066
# 896            0.838131                   1.999216       0.864131
# 897            0.500151                   0.054508       0.709845
# 898            0.810873                   1.748678       0.733141
# 899            0.810873                   1.748678       0.733141
#
#      lqt2_dist_weight_max  lqt2_dist_mean  lqt2_dist_weight_mean  \
# 0                1.402061        0.000950               1.402061
# 1                1.402061        0.000950               1.402061
# 2                1.402061        0.000950               1.402061
# 3                1.086629        0.011691               1.086629
# 4                1.086629        0.011691               1.086629
# ..                    ...             ...                    ...
# 895              1.536867        0.812867               4.871367
# 896              2.150489        0.835176               9.443791
# 897              0.198105        0.649226               0.146924
# 898              2.089740        0.781524               1.580555
# 899              2.089740        0.781524               1.580555
#
#      lqt2_dist_obs_max  lqt2_dist_weight_obs_max  lqt2_dist_obs_mean  \
# 0                  NaN                       NaN                 NaN
# 1                  NaN                       NaN                 NaN
# 2                  NaN                       NaN                 NaN
# 3                  NaN                       NaN                 NaN
# 4                  NaN                       NaN                 NaN
# ..                 ...                       ...                 ...
# 895           0.787066                  1.536867            0.812867
# 896           0.864131                  2.150489            0.835176
# 897           0.709845                  0.198105            0.649226
# 898           0.733141                  2.089740            0.781524
# 899           0.733141                  2.089740            0.781524
#
#      lqt2_dist_weight_obs_mean  lqt2_dist_obs_seq  lqt2_dist_weight_obs_seq
# 0                          NaN                NaN                       NaN
# 1                          NaN                NaN                       NaN
# 2                          NaN                NaN                       NaN
# 3                          NaN                NaN                       NaN
# 4                          NaN                NaN                       NaN
# ..                         ...                ...                       ...
# 895                   4.871367           0.891571                  0.912280
# 896                   9.443791           0.816971                  1.075925
# 897                   0.146924           0.480663                  0.109546
# 898                   1.580555           0.847661                  1.243046
# 899                   1.580555           0.847661                  1.243046
#
# [900 rows x 16 columns]

# %%
pearsoncorr = df.corr(method='pearson')
pearsoncorr
# Out:
#                            penetrance_lqt2      RMSF  lqt2_dist_sequence  \
# penetrance_lqt2                   1.000000  0.248801            0.624596
# RMSF                              0.248801  1.000000            0.280818
# lqt2_dist_sequence                0.624596  0.280818            1.000000
# lqt2_dist_weight_sequence         0.329894  0.164064            0.412763
# lqt2_dist_observed                0.470847  0.144867            0.963070
# lqt2_dist_weight_observed         0.405552  0.108039            0.555660
# lqt2_dist_max                     0.634100  0.260710            0.961023
# lqt2_dist_weight_max              0.335573  0.203704            0.395427
# lqt2_dist_mean                    0.639070  0.281547            0.970624
# lqt2_dist_weight_mean             0.417432  0.079597            0.522298
# lqt2_dist_obs_max                 0.469660  0.096867            0.915254
# lqt2_dist_weight_obs_max          0.442778  0.154720            0.586319
# lqt2_dist_obs_mean                0.480638  0.172796            0.933627
# lqt2_dist_weight_obs_mean         0.367684  0.001525            0.516621
# lqt2_dist_obs_seq                 0.464689  0.192436            0.997814
# lqt2_dist_weight_obs_seq          0.357833  0.117333            0.510714
#
#                            lqt2_dist_weight_sequence  lqt2_dist_observed  \
# penetrance_lqt2                             0.329894            0.470847
# RMSF                                        0.164064            0.144867
# lqt2_dist_sequence                          0.412763            0.963070
# lqt2_dist_weight_sequence                   1.000000            0.523688
# lqt2_dist_observed                          0.523688            1.000000
# lqt2_dist_weight_observed                   0.958943            0.583268
# lqt2_dist_max                               0.407917            0.959209
# lqt2_dist_weight_max                        0.824454            0.626489
# lqt2_dist_mean                              0.392700            0.967088
# lqt2_dist_weight_mean                       0.701340            0.543903
# lqt2_dist_obs_max                           0.551195            0.959209
# lqt2_dist_weight_obs_max                    0.729539            0.626489
# lqt2_dist_obs_mean                          0.496665            0.967088
# lqt2_dist_weight_obs_mean                   0.704290            0.543903
# lqt2_dist_obs_seq                           0.503074            0.963722
# lqt2_dist_weight_obs_seq                    0.999440            0.524133
#
#                            lqt2_dist_weight_observed  lqt2_dist_max  \
# penetrance_lqt2                             0.405552       0.634100
# RMSF                                        0.108039       0.260710
# lqt2_dist_sequence                          0.555660       0.961023
# lqt2_dist_weight_sequence                   0.958943       0.407917
# lqt2_dist_observed                          0.583268       0.959209
# lqt2_dist_weight_observed                   1.000000       0.609661
# lqt2_dist_max                               0.609661       1.000000
# lqt2_dist_weight_max                        0.826996       0.396724
# lqt2_dist_mean                              0.564574       0.985258
# lqt2_dist_weight_mean                       0.758225       0.541081
# lqt2_dist_obs_max                           0.609661       1.000000
# lqt2_dist_weight_obs_max                    0.826996       0.661243
# lqt2_dist_obs_mean                          0.564574       0.960174
# lqt2_dist_weight_obs_mean                   0.758225       0.598104
# lqt2_dist_obs_seq                           0.550367       0.913735
# lqt2_dist_weight_obs_seq                    0.958972       0.551976
#
#                            lqt2_dist_weight_max  lqt2_dist_mean  \
# penetrance_lqt2                        0.335573        0.639070
# RMSF                                   0.203704        0.281547
# lqt2_dist_sequence                     0.395427        0.970624
# lqt2_dist_weight_sequence              0.824454        0.392700
# lqt2_dist_observed                     0.626489        0.967088
# lqt2_dist_weight_observed              0.826996        0.564574
# lqt2_dist_max                          0.396724        0.985258
# lqt2_dist_weight_max                   1.000000        0.390154
# lqt2_dist_mean                         0.390154        1.000000
# lqt2_dist_weight_mean                  0.627865        0.515131
# lqt2_dist_obs_max                      0.661243        0.960174
# lqt2_dist_weight_obs_max               1.000000        0.614710
# lqt2_dist_obs_mean                     0.614710        1.000000
# lqt2_dist_weight_obs_mean              0.655036        0.528245
# lqt2_dist_obs_seq                      0.582749        0.932176
# lqt2_dist_weight_obs_seq               0.729507        0.498755
#
#                            lqt2_dist_weight_mean  lqt2_dist_obs_max  \
# penetrance_lqt2                         0.417432           0.469660
# RMSF                                    0.079597           0.096867
# lqt2_dist_sequence                      0.522298           0.915254
# lqt2_dist_weight_sequence               0.701340           0.551195
# lqt2_dist_observed                      0.543903           0.959209
# lqt2_dist_weight_observed               0.758225           0.609661
# lqt2_dist_max                           0.541081           1.000000
# lqt2_dist_weight_max                    0.627865           0.661243
# lqt2_dist_mean                          0.515131           0.960174
# lqt2_dist_weight_mean                   1.000000           0.598104
# lqt2_dist_obs_max                       0.598104           1.000000
# lqt2_dist_weight_obs_max                0.655036           0.661243
# lqt2_dist_obs_mean                      0.528245           0.960174
# lqt2_dist_weight_obs_mean               1.000000           0.598104
# lqt2_dist_obs_seq                       0.512506           0.913735
# lqt2_dist_weight_obs_seq                0.704795           0.551976
#
#                            lqt2_dist_weight_obs_max  lqt2_dist_obs_mean  \
# penetrance_lqt2                            0.442778            0.480638
# RMSF                                       0.154720            0.172796
# lqt2_dist_sequence                         0.586319            0.933627
# lqt2_dist_weight_sequence                  0.729539            0.496665
# lqt2_dist_observed                         0.626489            0.967088
# lqt2_dist_weight_observed                  0.826996            0.564574
# lqt2_dist_max                              0.661243            0.960174
# lqt2_dist_weight_max                       1.000000            0.614710
# lqt2_dist_mean                             0.614710            1.000000
# lqt2_dist_weight_mean                      0.655036            0.528245
# lqt2_dist_obs_max                          0.661243            0.960174
# lqt2_dist_weight_obs_max                   1.000000            0.614710
# lqt2_dist_obs_mean                         0.614710            1.000000
# lqt2_dist_weight_obs_mean                  0.655036            0.528245
# lqt2_dist_obs_seq                          0.582749            0.932176
# lqt2_dist_weight_obs_seq                   0.729507            0.498755
#
#                            lqt2_dist_weight_obs_mean  lqt2_dist_obs_seq  \
# penetrance_lqt2                             0.367684           0.464689
# RMSF                                        0.001525           0.192436
# lqt2_dist_sequence                          0.516621           0.997814
# lqt2_dist_weight_sequence                   0.704290           0.503074
# lqt2_dist_observed                          0.543903           0.963722
# lqt2_dist_weight_observed                   0.758225           0.550367
# lqt2_dist_max                               0.598104           0.913735
# lqt2_dist_weight_max                        0.655036           0.582749
# lqt2_dist_mean                              0.528245           0.932176
# lqt2_dist_weight_mean                       1.000000           0.512506
# lqt2_dist_obs_max                           0.598104           0.913735
# lqt2_dist_weight_obs_max                    0.655036           0.582749
# lqt2_dist_obs_mean                          0.528245           0.932176
# lqt2_dist_weight_obs_mean                   1.000000           0.512506
# lqt2_dist_obs_seq                           0.512506           1.000000
# lqt2_dist_weight_obs_seq                    0.704795           0.504550
#
#                            lqt2_dist_weight_obs_seq
# penetrance_lqt2                            0.357833
# RMSF                                       0.117333
# lqt2_dist_sequence                         0.510714
# lqt2_dist_weight_sequence                  0.999440
# lqt2_dist_observed                         0.524133
# lqt2_dist_weight_observed                  0.958972
# lqt2_dist_max                              0.551976
# lqt2_dist_weight_max                       0.729507
# lqt2_dist_mean                             0.498755
# lqt2_dist_weight_mean                      0.704795
# lqt2_dist_obs_max                          0.551976
# lqt2_dist_weight_obs_max                   0.729507
# lqt2_dist_obs_mean                         0.498755
# lqt2_dist_weight_obs_mean                  0.704795
# lqt2_dist_obs_seq                          0.504550
# lqt2_dist_weight_obs_seq                   1.000000
