# %% [markdown]
# # Change the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.datasets import make_regression
# Out:
# c:\python38\lib\site-packages\sklearn\experimental\enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
from scipy import stats
from datetime import datetime
from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('csv_data/all_lqt2_data_trunc(herg_combined_data).csv')

# %%
list(data)
# Out:
# ['Unnamed: 0',
#  'var',
#  'isoform',
#  'mut_type',
#  'resnum',
#  'lqt2',
#  'unaff',
#  'total_carriers',
#  'gnomAD',
#  'gnomAD_seq',
#  'weight',
#  'penetrance_lqt2',
#  'lqt2_penetranceBayesian_initial',
#  'lqt2_penetranceBayesian',
#  'pph2_prob',
#  'blast_pssm',
#  'provean_score',
#  'pamscore',
#  'aasimilaritymat',
#  'revel_score',
#  'hm_ssPeak',
#  'hm_tailPeak',
#  'hm_vhalfact',
#  'hm_vhalfinact',
#  'hm_recovfrominact',
#  'hm_taudeact_fast',
#  'ht_ssPeak',
#  'ht_tailPeak',
#  'ht_vhalfact',
#  'ht_vhalfinact',
#  'ht_recovfrominact',
#  'ht_taudeact_fast',
#  'lqt2_dist',
#  'lqt2_dist_weight',
#  'Structure',
#  'Function',
#  'p_mean_w',
#  'prior_mean_w',
#  'prior_mean',
#  'alpha',
#  'beta',
#  'lqt2_patho',
#  'p_mean_prior',
#  'RMSF',
#  'lqt2_dist_sequence',
#  'lqt2_dist_weight_sequence',
#  'lqt2_dist_observed',
#  'lqt2_dist_weight_observed',
#  'lqt2_dist_max',
#  'lqt2_dist_weight_max',
#  'lqt2_dist_mean',
#  'lqt2_dist_weight_mean',
# ...

# %%
na_counts = data.isna().sum()

# sort the columns by the number of NaN values in descending order
na_counts = na_counts.sort_values(ascending=False)

# print the result
print(na_counts)
# Out:
# ht_recovfrominact                  893
# hm_recovfrominact                  885
# ht_taudeact_fast                   879
# hm_ssPeak                          878
# ht_vhalfinact                      870
# ht_ssPeak                          866
# hm_vhalfinact                      865
# ht_vhalfact                        852
# hm_taudeact_fast                   849
# hm_vhalfact                        819
# ht_tailPeak                        806
# Function                           806
# hm_tailPeak                        786
# RMSF                               436
# gnomAD_seq                         408
# lqt2_dist_observed                 375
# lqt2_dist_weight_observed          375
# lqt2_dist_obs_max                  375
# lqt2_dist_weight_obs_max           375
# lqt2_dist_obs_mean                 375
# lqt2_dist_weight_obs_mean          375
# lqt2_dist_obs_seq                  375
# lqt2_dist_weight_obs_seq           375
# provean_score                       42
# ...

# %%
df = data

# %% [markdown]
# ##### Remove NAs from the dataset

# %%
#df = df.dropna(subset=['lqt2_dist_observed'])
#df = df.dropna(subset=['lqt2_dist_weight_observed'])
#df = df.dropna(subset=['lqt2_dist_obs_max'])
#df = df.dropna(subset=['lqt2_dist_weight_obs_max'])
#df = df.dropna(subset=['lqt2_dist_obs_mean'])
#df = df.dropna(subset=['lqt2_dist_weight_obs_mean'])
#df = df.dropna(subset=['lqt2_dist_obs_seq'])
#df = df.dropna(subset=['lqt2_dist_weight_obs_seq'])

# %%
df = df[df.lqt2_dist_observed.notnull()]
df = df[df.lqt2_dist_weight_observed.notnull()]
df = df[df.lqt2_dist_obs_max.notnull()]
df = df[df.lqt2_dist_weight_obs_max.notnull()]
df = df[df.lqt2_dist_obs_mean.notnull()]
df = df[df.lqt2_dist_weight_obs_mean.notnull()]
df = df[df.lqt2_dist_obs_seq.notnull()]
df = df[df.lqt2_dist_weight_obs_seq.notnull()]

# %%
df
# Out:
#      Unnamed: 0    var isoform  mut_type  resnum  lqt2  unaff  total_carriers  \
# 31           32   A32T       A  missense      32     1      0               1
# 32           33   A34T       A  missense      34     0      1               1
# 33           34  A382T       A  missense     382     1      1               2
# 34           35  A422T       A  missense     422     3      0               3
# 35           36  A429P       A  missense     429     2      1               3
# ..          ...    ...     ...       ...     ...   ...    ...             ...
# 895         896  Y611D       A  missense     611     1      0               1
# 896         897  Y616S       A  missense     616     3      0               3
# 897         898  Y812S       A  missense     812     0      1               1
# 898         899   Y99N       A  missense      99     1      0               1
# 899         900   Y99S       A  missense      99     2      0               2
#
# ...

# %%
na_counts = data.isna().sum()

# sort the columns by the number of NaN values in descending order
na_counts = na_counts.sort_values(ascending=False)

# print the result
print(na_counts)
# Out:
# ht_recovfrominact                  893
# hm_recovfrominact                  885
# ht_taudeact_fast                   879
# hm_ssPeak                          878
# ht_vhalfinact                      870
# ht_ssPeak                          866
# hm_vhalfinact                      865
# ht_vhalfact                        852
# hm_taudeact_fast                   849
# hm_vhalfact                        819
# ht_tailPeak                        806
# Function                           806
# hm_tailPeak                        786
# RMSF                               436
# gnomAD_seq                         408
# lqt2_dist_observed                 375
# lqt2_dist_weight_observed          375
# lqt2_dist_obs_max                  375
# lqt2_dist_weight_obs_max           375
# lqt2_dist_obs_mean                 375
# lqt2_dist_weight_obs_mean          375
# lqt2_dist_obs_seq                  375
# lqt2_dist_weight_obs_seq           375
# provean_score                       42
# ...

# %%
m = df['RMSF'].max()
df['RMSF'] = df['RMSF'].fillna(m)

# %%
#df.to_csv('csv_data/new_herg_combined_data.csv', index=True)
