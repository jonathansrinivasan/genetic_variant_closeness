# %% [markdown]
# # Data Dictionary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### updated_h2dist

# %%
updated_h2dist = pd.read_csv('csv_data/updated_h2dist.csv')

# %%
updated_h2dist
# Out:
#        Unnamed: 0   V1   V2  V3     V4      V5      V7    V8       V5.2  \
# 0               2    1    1  BC  right  1.0000  1.0000   0.0   2.910000
# 1               3    1    2  DD  intra  0.5183  0.1449   3.9   5.614509
# 2               4    1    3  DD  intra  0.3910  0.1069   5.7   7.442455
# 3               5    1    4  BB  intra  0.2733  0.0837  10.2  10.647640
# 4               6    1    5  DD  intra  0.2727  0.0714   9.4  10.671067
# ...           ...  ...  ...  ..    ...     ...     ...   ...        ...
# 56194      388126  863  859  CC  intra  0.3262  0.0924  12.5   8.920907
# 56195      388127  863  860  CC  intra  0.3266  0.0927   9.5   8.909982
# 56196      388128  863  861  CC  intra  0.5123  0.1406   5.8   5.680265
# 56197      388129  863  862  CC  intra  0.5118  0.1430   3.9   5.685815
# 56198      388130  863  863  CD  right  1.0000  1.0000   0.0   2.910000
#
#             V7.2
# 0       0.878500
# 1       6.062802
# 2       8.217961
# 3      10.495818
# ...

# %%
list(updated_h2dist)
# Out:
# ['Unnamed: 0', 'V1', 'V2', 'V3', 'V4', 'V5', 'V7', 'V8', 'V5.2', 'V7.2']

# %% [markdown]
# ### all_lqt2_data_trunc - herg_combined_data (clinical)

# %%
all_lqt2_data_trunc = pd.read_csv('csv_data/all_lqt2_data_trunc(herg_combined_data).csv')

# %%
all_lqt2_data_trunc
# Out:
#      Unnamed: 0     var isoform  mut_type  resnum  lqt2  unaff  \
# 0             1  A1017S       A  missense    1017     0      1
# 1             2  A1017T       A  missense    1017     0      2
# 2             3  A1017V       A  missense    1017     0      3
# 3             4  A1058E       A  missense    1058     0      1
# 4             5  A1058T       A  missense    1058     0      2
# ..          ...     ...     ...       ...     ...   ...    ...
# 895         896   Y611D       A  missense     611     1      0
# 896         897   Y616S       A  missense     616     3      0
# 897         898   Y812S       A  missense     812     0      1
# 898         899    Y99N       A  missense      99     1      0
# 899         900    Y99S       A  missense      99     2      0
#
#      total_carriers  gnomAD  gnomAD_seq  ...  lqt2_dist_max  \
# 0                 1     1.0    156338.0  ...       0.000950
# 1                 2     2.0    156338.0  ...       0.000950
# ...

# %%
all_lqt2_data_trunc['penetrance_lqt2'].unique()
# Out:
# array([0.00000000e+00, 3.33333333e-01, 2.00000000e-01, 1.00000000e+00,
#        2.77777778e-02, 5.00000000e-01, 6.66666667e-01, 5.83333333e-01,
#        8.57142857e-01, 8.92857143e-01, 8.97435897e-01, 9.79591837e-01,
#        7.50000000e-01, 6.02409639e-02, 4.00000000e-01, 5.71428571e-01,
#        1.66666667e-01, 7.00000000e-01, 9.09090909e-01, 3.07692308e-01,
#        1.11111111e-01, 6.00000000e-01, 7.36842105e-01, 8.75000000e-01,
#        7.77777778e-01, 1.42857143e-01, 7.14285714e-01, 9.47368421e-01,
#        2.82051282e-01, 6.95652174e-01, 9.00000000e-01, 8.00000000e-01,
#        2.50000000e-01, 4.63414634e-01, 7.61904762e-01, 1.00000000e-01,
#        6.84210526e-01, 2.70444569e-04, 1.04166667e-02, 4.02061856e-01,
#        6.12903226e-01, 3.63636364e-01, 8.88888889e-01, 2.85714286e-01,
#        5.78947368e-01, 2.01342282e-02, 5.55555556e-02, 4.54545455e-02,
#        1.59387950e-03, 1.68539326e-02, 3.65853659e-01, 1.29032258e-01,
# ...

# %%
all_lqt2_data_trunc['weight'].unique()
# Out:
# array([0.00990099, 0.50248756, 0.66777409, 0.83361065, 0.93337775,
#        0.75062344, 0.88901221, 0.97222994, 0.94447529, 0.97059688,
#        0.8003992 , 0.91673605, 0.85734665, 0.96429846, 0.97436555,
#        0.979596  , 0.87515605, 0.98795326, 0.90917348, 0.9000999 ,
#        0.92313605, 0.94121105, 0.98485078, 0.97369113, 0.95240362,
#        0.96155325, 0.95654063, 0.97500625, 0.94739611, 0.98666844,
#        0.93753904, 0.9756157 , 0.92862241, 0.9999792 , 0.99479194,
#        0.98969178, 0.95456611, 0.96775234, 0.96297668, 0.98765584,
#        0.99664441, 0.95002499, 0.99968123, 0.95835069, 0.99719109,
#        0.99187058, 0.98913162, 0.99415239, 0.96875976, 0.98276159,
#        0.9909918 , 0.96001599, 0.98529628, 0.98077293, 0.98148491,
#        0.97674959, 0.97619614])

# %%
all_lqt2_data_trunc['lqt2_penetranceBayesian_initial']
# Out:
# 0      0.257067
# 1      0.199775
# 2      0.163366
# 3      0.257067
# 4      0.199775
#          ...
# 895    0.543850
# 896    0.710117
# 897    0.257067
# 898    0.543850
# 899    0.645512
# Name: lqt2_penetranceBayesian_initial, Length: 900, dtype: float64

# %%
all_lqt2_data_trunc['lqt2_penetranceBayesian'].unique()
# Out:
# array([2.57066994e-01, 1.99774879e-01, 1.63365801e-01, 3.45616333e-01,
#        1.05618640e-01, 2.22816434e-01, 1.38182049e-01, 5.43850373e-01,
#        7.80346556e-02, 4.92733318e-02, 4.22643299e-01, 4.37537198e-02,
#        7.10117398e-01, 5.27866865e-01, 2.45671484e-02, 7.87554140e-01,
#        5.45068427e-01, 7.26933168e-01, 8.49425027e-01, 8.65245054e-01,
#        9.49684883e-01, 8.54757741e-02, 6.00648829e-01, 6.45511720e-01,
#        6.89740388e-02, 1.19725667e-01, 3.86857056e-01, 5.16117311e-01,
#        6.64627818e-02, 2.23446566e-01, 7.17853601e-02, 4.46493236e-01,
#        5.78797139e-02, 9.44855983e-02, 6.32370502e-01, 8.07920132e-01,
#        8.32341096e-01, 3.16161646e-01, 4.59990026e-02, 1.65089948e-01,
#        5.52286911e-01, 7.54804422e-01, 1.30883379e-02, 8.12586195e-01,
#        7.13720807e-01, 7.52971889e-01, 5.76930343e-01, 6.87421701e-01,
#        1.65895528e-01, 8.48328477e-01, 3.14663486e-02, 6.21525239e-01,
# ...

# %%
all_lqt2_data_trunc['Structure'].unique()
# Out:
# array(['Non_Hotspot', 'Mild_Hotspot', 'Hotspot'], dtype=object)

# %%
all_lqt2_data_trunc['lqt2_dist'].unique()
# Out:
# array([9.50384475e-04, 1.16905117e-02, 9.27745099e-04, 2.22366295e-02,
#        2.34250154e-04, 1.58024878e-02, 3.62074799e-03, 8.00147637e-01,
#        6.52493718e-01, 1.59188728e-01, 5.88068015e-02, 6.42215098e-02,
#        7.64801303e-02, 2.07294873e-01, 5.68972116e-01, 7.15286663e-02,
#        2.26553258e-01, 1.24865864e-02, 2.26373841e-01, 6.43162110e-02,
#        2.55717981e-03, 8.79150109e-02, 1.50198018e-01, 6.32075173e-01,
#        6.12544042e-01, 3.48164834e-01, 7.71944327e-01, 2.62035704e-01,
#        5.47380999e-01, 7.89634931e-01, 9.85532429e-02, 3.98186149e-01,
#        5.46973565e-01, 6.82776435e-01, 5.35766054e-01, 5.46446322e-01,
#        1.52272365e-01, 5.84608589e-01, 6.23130260e-01, 8.54260284e-01,
#        7.23853098e-01, 7.46171487e-01, 7.45217709e-01, 6.40578189e-01,
#        8.67222394e-01, 8.71600280e-01, 3.21939062e-01, 2.31570749e-02,
#        4.87119719e-01, 1.02739195e-01, 2.70828384e-01, 1.73162252e-01,
# ...

# %%
# penetrance_lqt2 
list(all_lqt2_data_trunc)
# Out:
# ['Unnamed: 0',
#  'var',
#  'isoform',
#  'mut_type',
#  'resnum',
#  'lqt2',
#  'unaff',
#  'total_carriers',
#  'gnomAD',
#  'gnomAD_seq',
#  'weight',
#  'penetrance_lqt2',
#  'lqt2_penetranceBayesian_initial',
#  'lqt2_penetranceBayesian',
#  'pph2_prob',
#  'blast_pssm',
#  'provean_score',
#  'pamscore',
#  'aasimilaritymat',
#  'revel_score',
#  'hm_ssPeak',
#  'hm_tailPeak',
#  'hm_vhalfact',
#  'hm_vhalfinact',
#  'hm_recovfrominact',
#  'hm_taudeact_fast',
#  'ht_ssPeak',
#  'ht_tailPeak',
#  'ht_vhalfact',
#  'ht_vhalfinact',
#  'ht_recovfrominact',
#  'ht_taudeact_fast',
#  'lqt2_dist',
#  'lqt2_dist_weight',
#  'Structure',
#  'Function',
#  'p_mean_w',
#  'prior_mean_w',
#  'prior_mean',
#  'alpha',
#  'beta',
#  'lqt2_patho',
#  'p_mean_prior',
#  'RMSF',
#  'lqt2_dist_sequence',
#  'lqt2_dist_weight_sequence',
#  'lqt2_dist_observed',
#  'lqt2_dist_weight_observed',
#  'lqt2_dist_max',
#  'lqt2_dist_weight_max',
#  'lqt2_dist_mean',
#  'lqt2_dist_weight_mean',
# ...

# %%
print(all_lqt2_data_trunc.dtypes)
# Out:
# Unnamed: 0                           int64
# var                                 object
# isoform                             object
# mut_type                            object
# resnum                               int64
# lqt2                                 int64
# unaff                                int64
# total_carriers                       int64
# gnomAD                             float64
# gnomAD_seq                         float64
# weight                             float64
# penetrance_lqt2                    float64
# lqt2_penetranceBayesian_initial    float64
# lqt2_penetranceBayesian            float64
# pph2_prob                          float64
# blast_pssm                         float64
# provean_score                      float64
# pamscore                           float64
# aasimilaritymat                    float64
# revel_score                        float64
# hm_ssPeak                          float64
# hm_tailPeak                        float64
# ...

# %% [markdown]
# ### all_brs1_data_trunc

# %%
all_brs1_data_trunc = pd.read_csv('csv_data/all_brs1_data_trunc.csv')

# %%
all_brs1_data_trunc
# Out:
#       Unnamed: 0     var ref       pos alt Structure_BrS  brs1_penetrance  \
# 0              1  A1006S   C  38622634   A   Non_Hotspot              0.0
# 1              2  A1050T   C  38622502   T   Non_Hotspot              0.0
# 2              3  A1052D   G  38622495   T   Non_Hotspot              0.0
# 3              4  A1088T   C  38620953   T   Non_Hotspot              0.0
# 4              5  A1088V   G  38620952   A   Non_Hotspot              0.0
# ...          ...     ...  ..       ...  ..           ...              ...
# 2419        2420    Y68C   T  38674596   C   Non_Hotspot              0.0
# 2420        2421   Y694C   T  38639401   C   Non_Hotspot              0.0
# 2421        2422   Y774C   T  38629006   C  Mild_Hotspot              0.0
# 2422        2423   Y774D   A  38629007   C  Mild_Hotspot              0.0
# 2423        2424    Y87C   T  38674539   C       Hotspot              1.0
#
#       Function PREDICTION_provean  provean_score  ...  unaff_gnomad    weight  \
# ...

# %%
list(all_brs1_data_trunc)
# Out:
# ['Unnamed: 0',
#  'var',
#  'ref',
#  'pos',
#  'alt',
#  'Structure_BrS',
#  'brs1_penetrance',
#  'Function',
#  'PREDICTION_provean',
#  'provean_score',
#  'eaRate',
#  'prediction',
#  'pph2_prob',
#  'blastpssm',
#  'pamscore',
#  'SIFT_score',
#  'PREDICTION_sift',
#  'Structure_LQT',
#  'lqt3_penetrance',
#  'resnum',
#  'REVEL',
#  'lqt3',
#  'brs1',
#  'unaff',
#  'other',
#  'gnomAD',
#  'gnomAD_seq',
#  'total_carriers',
#  'unaff_gnomad',
#  'weight',
#  'brs1_penetranceBayesian_initial',
#  'brs1_penetranceBayesian',
#  'brs1_dist',
#  'brs1_dist_weight',
#  'brs1_dist_sequence',
#  'brs1_dist_weight_sequence',
#  'brs1_dist_correlated',
#  'brs1_dist_weight_correlated']

# %%
all_brs1_data_trunc_test = pd.read_csv('csv_data/all_brs1_data_trunc_test.csv')

# %%
all_brs1_data_trunc_test
# Out:
#       Unnamed: 0     var ref       pos alt Structure_BrS  brs1_penetrance  \
# 0              1  A1006S   C  38622634   A   Non_Hotspot              0.0
# 1              2  A1050T   C  38622502   T   Non_Hotspot              0.0
# 2              3  A1052D   G  38622495   T   Non_Hotspot              0.0
# 3              4  A1088T   C  38620953   T   Non_Hotspot              0.0
# 4              5  A1088V   G  38620952   A   Non_Hotspot              0.0
# ...          ...     ...  ..       ...  ..           ...              ...
# 2010        2420    Y68C   T  38674596   C   Non_Hotspot              0.0
# 2011        2421   Y694C   T  38639401   C   Non_Hotspot              0.0
# 2012        2422   Y774C   T  38629006   C  Mild_Hotspot              0.0
# 2013        2423   Y774D   A  38629007   C  Mild_Hotspot              0.0
# 2014        2424    Y87C   T  38674539   C       Hotspot              1.0
#
#       Function PREDICTION_provean  provean_score  ...  \
# ...

# %%
list(all_brs1_data_trunc_test)
# Out:
# ['Unnamed: 0',
#  'var',
#  'ref',
#  'pos',
#  'alt',
#  'Structure_BrS',
#  'brs1_penetrance',
#  'Function',
#  'PREDICTION_provean',
#  'provean_score',
#  'eaRate',
#  'prediction',
#  'pph2_prob',
#  'blastpssm',
#  'pamscore',
#  'SIFT_score',
#  'PREDICTION_sift',
#  'Structure_LQT',
#  'lqt3_penetrance',
#  'resnum',
#  'REVEL',
#  'lqt3',
#  'brs1',
#  'unaff',
#  'other',
#  'gnomAD',
#  'gnomAD_seq',
#  'total_carriers',
#  'unaff_gnomad',
#  'weight',
#  'brs1_penetranceBayesian_initial',
#  'brs1_penetranceBayesian',
#  'brs1_dist',
#  'brs1_dist_weight',
#  'brs1_dist_sequence',
#  'brs1_dist_weight_sequence',
#  'brs1_dist_correlated',
#  'brs1_dist_weight_correlated',
#  'brs1_dist_inverse',
#  'brs1_dist_inverse_weight',
#  'brs1_dist_inverse_cor',
#  'brs1_dist_inverse_weight_cor',
#  'brs1_dist_inverse_seq',
#  'brs1_dist_inverse_weight_seq',
#  'brs1_dist_2inverse',
#  'brs1_dist_2inverse_weight',
#  'brs1_dist_2inverse_cor',
#  'brs1_dist_2inverse_weight_cor',
# ...

# %% [markdown]
# Check Differences

# %%
all_brs1_data_trunc.compare(all_brs1_data_trunc_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <module>
# ----> 1 all_brs1_data_trunc.compare(all_brs1_data_trunc_test)
#
# File c:\python38\lib\site-packages\pandas\core\frame.py:7187, in DataFrame.compare(self, other, align_axis, keep_shape, keep_equal)
#    7074 @doc(
#    7075     _shared_docs["compare"],
#    7076     """
#    (...)
#    7185     keep_equal: bool = False,
#    7186 ) -> DataFrame:
# -> 7187     return super().compare(
#    7188         other=other,
#    7189         align_axis=align_axis,
#    7190         keep_shape=keep_shape,
#    7191         keep_equal=keep_equal,
#    7192     )
#
# File c:\python38\lib\site-packages\pandas\core\generic.py:8646, in NDFrame.compare(self, other, align_axis, keep_shape, keep_equal)
#    8641     cls_self, cls_other = type(self).__name__, type(other).__name__
#    8642     raise TypeError(
# ...

# %% [markdown]
# ### all_data_new

# %%
all_data_funcdist_new = pd.read_csv('csv_data/all_data_funcdist_new.csv')

# %%
all_data_funcdist_new

# %%
list(all_data_funcdist_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <module>
# ----> 1 list(all_data_funcdist_new)
#
# NameError: name 'all_data_funcdist_new' is not defined

# %%
all_max_data_new = pd.read_csv('csv_data/all_max_data_new.csv')

# %%
all_max_data_new
# Out:
#      Unnamed: 0     var isoform  mut_type  resnum  lqt2  unaff  \
# 0             1  A1017S       A  missense    1017     0      1
# 1             2  A1017T       A  missense    1017     0      2
# 2             3  A1017V       A  missense    1017     0      3
# 3             4  A1058E       A  missense    1058     0      1
# 4             5  A1058T       A  missense    1058     0      2
# ..          ...     ...     ...       ...     ...   ...    ...
# 895         898   Y611D       A  missense     611     1      0
# 896         899   Y616S       A  missense     616     3      0
# 897         900   Y812S       A  missense     812     0      1
# 898         901    Y99N       A  missense      99     1      0
# 899         902    Y99S       A  missense      99     2      0
#
#      total_carriers  gnomAD  gnomAD_seq  ...    Structure  Function  p_mean_w  \
# 0                 1     1.0    156338.0  ...  Non_Hotspot       NaN  0.054923
# ...

# %%
list(all_max_data_new)
# Out:
# ['Unnamed: 0',
#  'var',
#  'isoform',
#  'mut_type',
#  'resnum',
#  'lqt2',
#  'unaff',
#  'total_carriers',
#  'gnomAD',
#  'gnomAD_seq',
#  'weight',
#  'penetrance_lqt2',
#  'lqt2_penetranceBayesian_initial',
#  'lqt2_penetranceBayesian',
#  'pph2_prob',
#  'blast_pssm',
#  'provean_score',
#  'pamscore',
#  'aasimilaritymat',
#  'revel_score',
#  'hm_ssPeak',
#  'hm_tailPeak',
#  'hm_vhalfact',
#  'hm_vhalfinact',
#  'hm_recovfrominact',
#  'hm_taudeact_fast',
#  'ht_ssPeak',
#  'ht_tailPeak',
#  'ht_vhalfact',
#  'ht_vhalfinact',
#  'ht_recovfrominact',
#  'ht_taudeact_fast',
#  'lqt2_dist',
#  'lqt2_dist_weight',
#  'Structure',
#  'Function',
#  'p_mean_w',
#  'prior_mean_w',
#  'prior_mean',
#  'alpha',
#  'beta',
#  'lqt2_patho',
#  'p_mean_prior',
#  'Mean']

# %%
all_mean_data_new = pd.read_csv('csv_data/all_mean_data_new.csv')

# %%
all_mean_data_new
# Out:
#      Unnamed: 0     var isoform  mut_type  resnum  lqt2  unaff  \
# 0             1  A1017S       A  missense    1017     0      1
# 1             2  A1017T       A  missense    1017     0      2
# 2             3  A1017V       A  missense    1017     0      3
# 3             4  A1058E       A  missense    1058     0      1
# 4             5  A1058T       A  missense    1058     0      2
# ..          ...     ...     ...       ...     ...   ...    ...
# 895         898   Y611D       A  missense     611     1      0
# 896         899   Y616S       A  missense     616     3      0
# 897         900   Y812S       A  missense     812     0      1
# 898         901    Y99N       A  missense      99     1      0
# 899         902    Y99S       A  missense      99     2      0
#
#      total_carriers  gnomAD  gnomAD_seq  ...    Structure  Function  p_mean_w  \
# 0                 1     1.0    156338.0  ...  Non_Hotspot       NaN  0.054923
# ...

# %%
list(all_mean_data_new)
# Out:
# ['Unnamed: 0',
#  'var',
#  'isoform',
#  'mut_type',
#  'resnum',
#  'lqt2',
#  'unaff',
#  'total_carriers',
#  'gnomAD',
#  'gnomAD_seq',
#  'weight',
#  'penetrance_lqt2',
#  'lqt2_penetranceBayesian_initial',
#  'lqt2_penetranceBayesian',
#  'pph2_prob',
#  'blast_pssm',
#  'provean_score',
#  'pamscore',
#  'aasimilaritymat',
#  'revel_score',
#  'hm_ssPeak',
#  'hm_tailPeak',
#  'hm_vhalfact',
#  'hm_vhalfinact',
#  'hm_recovfrominact',
#  'hm_taudeact_fast',
#  'ht_ssPeak',
#  'ht_tailPeak',
#  'ht_vhalfact',
#  'ht_vhalfinact',
#  'ht_recovfrominact',
#  'ht_taudeact_fast',
#  'lqt2_dist',
#  'lqt2_dist_weight',
#  'Structure',
#  'Function',
#  'p_mean_w',
#  'prior_mean_w',
#  'prior_mean',
#  'alpha',
#  'beta',
#  'lqt2_patho',
#  'p_mean_prior',
#  'Mean']

# %%
all_data_funcdist_new.compare(all_max_data_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <module>
# ----> 1 all_data_funcdist_new.compare(all_max_data_new)
#
# NameError: name 'all_data_funcdist_new' is not defined

# %%
all_mean_data_new.compare(all_max_data_new)
# Out:
#     lqt2_dist           lqt2_dist_weight
#          self     other             self     other
# 31   0.652884  0.636009         0.722193  1.398746
# 32   0.678245  0.649212         0.307284  0.625917
# 33   0.305536  0.399854         0.061223  0.343553
# 34   0.715120  0.723834         0.694865  0.637048
# 35   0.341708  0.367530         0.937471  0.698530
# ..        ...       ...              ...       ...
# 895  0.812867  0.787066         4.871367  1.536867
# 896  0.835176  0.864131         9.443791  2.150489
# 897  0.649226  0.709845         0.146924  0.198105
# 898  0.781524  0.733141         1.580555  2.089740
# 899  0.781524  0.733141         1.580555  2.089740
#
# [525 rows x 4 columns]

# %%
all_data_funcdist_new.compare(all_lqt2_data_trunc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <module>
# ----> 1 all_data_funcdist_new.compare(all_lqt2_data_trunc)
#
# NameError: name 'all_data_funcdist_new' is not defined

# %% [markdown]
# ### obs_data

# %%
obs_data_funcdist_new = pd.read_csv('csv_data/obs_data_funcdist_new.csv')

# %%
obs_data_funcdist_new
# Out:
#      Unnamed: 0    var isoform  mut_type  resnum  lqt2  unaff  total_carriers  \
# 0            32   A32T       A  missense      32     1      0               1
# 1            33   A34T       A  missense      34     0      1               1
# 2            35  A382T       A  missense     382     1      1               2
# 3            36  A422T       A  missense     422     3      0               3
# 4            37  A429P       A  missense     429     2      1               3
# ..          ...    ...     ...       ...     ...   ...    ...             ...
# 520         898  Y611D       A  missense     611     1      0               1
# 521         899  Y616S       A  missense     616     3      0               3
# 522         900  Y812S       A  missense     812     0      1               1
# 523         901   Y99N       A  missense      99     1      0               1
# 524         902   Y99S       A  missense      99     2      0               2
#
# ...

# %%
list(obs_data_funcdist_new)
# Out:
# ['Unnamed: 0',
#  'var',
#  'isoform',
#  'mut_type',
#  'resnum',
#  'lqt2',
#  'unaff',
#  'total_carriers',
#  'gnomAD',
#  'gnomAD_seq',
#  'weight',
#  'penetrance_lqt2',
#  'lqt2_penetranceBayesian_initial',
#  'lqt2_penetranceBayesian',
#  'pph2_prob',
#  'blast_pssm',
#  'provean_score',
#  'pamscore',
#  'aasimilaritymat',
#  'revel_score',
#  'hm_ssPeak',
#  'hm_tailPeak',
#  'hm_vhalfact',
#  'hm_vhalfinact',
#  'hm_recovfrominact',
#  'hm_taudeact_fast',
#  'ht_ssPeak',
#  'ht_tailPeak',
#  'ht_vhalfact',
#  'ht_vhalfinact',
#  'ht_recovfrominact',
#  'ht_taudeact_fast',
#  'lqt2_dist',
#  'lqt2_dist_weight',
#  'Structure',
#  'Function',
#  'p_mean_w',
#  'prior_mean_w',
#  'prior_mean',
#  'alpha',
#  'beta',
#  'lqt2_patho',
#  'p_mean_prior',
#  'Mean']

# %%
obs_max_data_new = pd.read_csv('csv_data/obs_max_data_new.csv')

# %%
obs_max_data_new
# Out:
#      Unnamed: 0    var isoform  mut_type  resnum  lqt2  unaff  total_carriers  \
# 0            32   A32T       A  missense      32     1      0               1
# 1            33   A34T       A  missense      34     0      1               1
# 2            35  A382T       A  missense     382     1      1               2
# 3            36  A422T       A  missense     422     3      0               3
# 4            37  A429P       A  missense     429     2      1               3
# ..          ...    ...     ...       ...     ...   ...    ...             ...
# 520         898  Y611D       A  missense     611     1      0               1
# 521         899  Y616S       A  missense     616     3      0               3
# 522         900  Y812S       A  missense     812     0      1               1
# 523         901   Y99N       A  missense      99     1      0               1
# 524         902   Y99S       A  missense      99     2      0               2
#
# ...

# %%
list(obs_max_data_new)
# Out:
# ['Unnamed: 0',
#  'var',
#  'isoform',
#  'mut_type',
#  'resnum',
#  'lqt2',
#  'unaff',
#  'total_carriers',
#  'gnomAD',
#  'gnomAD_seq',
#  'weight',
#  'penetrance_lqt2',
#  'lqt2_penetranceBayesian_initial',
#  'lqt2_penetranceBayesian',
#  'pph2_prob',
#  'blast_pssm',
#  'provean_score',
#  'pamscore',
#  'aasimilaritymat',
#  'revel_score',
#  'hm_ssPeak',
#  'hm_tailPeak',
#  'hm_vhalfact',
#  'hm_vhalfinact',
#  'hm_recovfrominact',
#  'hm_taudeact_fast',
#  'ht_ssPeak',
#  'ht_tailPeak',
#  'ht_vhalfact',
#  'ht_vhalfinact',
#  'ht_recovfrominact',
#  'ht_taudeact_fast',
#  'lqt2_dist',
#  'lqt2_dist_weight',
#  'Structure',
#  'Function',
#  'p_mean_w',
#  'prior_mean_w',
#  'prior_mean',
#  'alpha',
#  'beta',
#  'lqt2_patho',
#  'p_mean_prior',
#  'Mean']

# %%
obs_mean_data_new = pd.read_csv('csv_data/obs_mean_data_new.csv')

# %%
obs_mean_data_new
# Out:
#      Unnamed: 0    var isoform  mut_type  resnum  lqt2  unaff  total_carriers  \
# 0            32   A32T       A  missense      32     1      0               1
# 1            33   A34T       A  missense      34     0      1               1
# 2            35  A382T       A  missense     382     1      1               2
# 3            36  A422T       A  missense     422     3      0               3
# 4            37  A429P       A  missense     429     2      1               3
# ..          ...    ...     ...       ...     ...   ...    ...             ...
# 520         898  Y611D       A  missense     611     1      0               1
# 521         899  Y616S       A  missense     616     3      0               3
# 522         900  Y812S       A  missense     812     0      1               1
# 523         901   Y99N       A  missense      99     1      0               1
# 524         902   Y99S       A  missense      99     2      0               2
#
# ...

# %%
list(obs_mean_data_new)
# Out:
# ['Unnamed: 0',
#  'var',
#  'isoform',
#  'mut_type',
#  'resnum',
#  'lqt2',
#  'unaff',
#  'total_carriers',
#  'gnomAD',
#  'gnomAD_seq',
#  'weight',
#  'penetrance_lqt2',
#  'lqt2_penetranceBayesian_initial',
#  'lqt2_penetranceBayesian',
#  'pph2_prob',
#  'blast_pssm',
#  'provean_score',
#  'pamscore',
#  'aasimilaritymat',
#  'revel_score',
#  'hm_ssPeak',
#  'hm_tailPeak',
#  'hm_vhalfact',
#  'hm_vhalfinact',
#  'hm_recovfrominact',
#  'hm_taudeact_fast',
#  'ht_ssPeak',
#  'ht_tailPeak',
#  'ht_vhalfact',
#  'ht_vhalfinact',
#  'ht_recovfrominact',
#  'ht_taudeact_fast',
#  'lqt2_dist',
#  'lqt2_dist_weight',
#  'Structure',
#  'Function',
#  'p_mean_w',
#  'prior_mean_w',
#  'prior_mean',
#  'alpha',
#  'beta',
#  'lqt2_patho',
#  'p_mean_prior',
#  'Mean']

# %%
obs_data_funcdist_new.compare(obs_max_data_new)
# Out:
#     lqt2_dist           lqt2_dist_weight
#          self     other             self     other
# 0    0.632075  0.636009         1.093957  1.398746
# 1    0.612544  0.649212         0.756702  0.625917
# 2    0.348165  0.399854         0.506700  0.343553
# 3    0.771944  0.723834         0.550769  0.637048
# 4    0.262036  0.367530         1.168175  0.698530
# ..        ...       ...              ...       ...
# 520  0.848384  0.787066         1.428122  1.536867
# 521  0.838131  0.864131         1.999216  2.150489
# 522  0.500151  0.709845         0.054508  0.198105
# 523  0.810873  0.733141         1.748678  2.089740
# 524  0.810873  0.733141         1.748678  2.089740
#
# [525 rows x 4 columns]

# %%
obs_data_funcdist_new.compare(obs_mean_data_new)
# Out:
#     lqt2_dist           lqt2_dist_weight
#          self     other             self     other
# 0    0.632075  0.652884         1.093957  0.722193
# 1    0.612544  0.678245         0.756702  0.307284
# 2    0.348165  0.305536         0.506700  0.061223
# 3    0.771944  0.715120         0.550769  0.694865
# 4    0.262036  0.341708         1.168175  0.937471
# ..        ...       ...              ...       ...
# 520  0.848384  0.812867         1.428122  4.871367
# 521  0.838131  0.835176         1.999216  9.443791
# 522  0.500151  0.649226         0.054508  0.146924
# 523  0.810873  0.781524         1.748678  1.580555
# 524  0.810873  0.781524         1.748678  1.580555
#
# [525 rows x 4 columns]

# %% [markdown]
# ### scn5a_brs1

# %%
scn5a_brs1_all_data = pd.read_csv('csv_data/scn5a_brs1_all_data.csv')

# %%
scn5a_brs1_all_data
# Out:
#       Unnamed: 0     var ref       pos alt Structure_BrS  brs1_penetrance  \
# 0              4  A1006S   C  38622634   A   Non_Hotspot              0.0
# 1             11  A1050T   C  38622502   T   Non_Hotspot              0.0
# 2             13  A1052D   G  38622495   T   Non_Hotspot              0.0
# 3             29  A1088T   C  38620953   T   Non_Hotspot              0.0
# 4             30  A1088V   G  38620952   A   Non_Hotspot              0.0
# ...          ...     ...  ..       ...  ..           ...              ...
# 1369       13886    Y68C   T  38674596   C   Non_Hotspot              0.0
# 1370       13892   Y694C   T  38639401   C   Non_Hotspot              0.0
# 1371       13904   Y774C   T  38629006   C  Mild_Hotspot              0.0
# 1372       13905   Y774D   A  38629007   C  Mild_Hotspot              0.0
# 1373       13928    Y87C   T  38674539   C       Hotspot              1.0
#
#       Function PREDICTION_provean  provean_score  ...  other gnomAD  \
# ...

# %%
list(scn5a_brs1_all_data)
# Out:
# ['Unnamed: 0',
#  'var',
#  'ref',
#  'pos',
#  'alt',
#  'Structure_BrS',
#  'brs1_penetrance',
#  'Function',
#  'PREDICTION_provean',
#  'provean_score',
#  'eaRate',
#  'prediction',
#  'pph2_prob',
#  'blastpssm',
#  'pamscore',
#  'SIFT_score',
#  'PREDICTION_sift',
#  'Structure_LQT',
#  'lqt3_penetrance',
#  'resnum',
#  'REVEL',
#  'lqt3',
#  'brs1',
#  'unaff',
#  'other',
#  'gnomAD',
#  'gnomAD_seq',
#  'total_carriers',
#  'unaff_gnomad',
#  'weight',
#  'brs1_penetranceBayesian_initial',
#  'brs1_penetranceBayesian',
#  'brs1_dist',
#  'brs1_dist_weight']

# %%
scn5a_brs1_cor_data = pd.read_csv('csv_data/scn5a_brs1_cor_data.csv')

# %%
scn5a_brs1_cor_data
# Out:
#      Unnamed: 0     var ref       pos alt Structure_BrS  brs1_penetrance  \
# 0             4  A1006S   C  38622634   A   Non_Hotspot              0.0
# 1            11  A1050T   C  38622502   T   Non_Hotspot              0.0
# 2            13  A1052D   G  38622495   T   Non_Hotspot              0.0
# 3            29  A1088T   C  38620953   T   Non_Hotspot              0.0
# 4            30  A1088V   G  38620952   A   Non_Hotspot              0.0
# ..          ...     ...  ..       ...  ..           ...              ...
# 960       13886    Y68C   T  38674596   C   Non_Hotspot              0.0
# 961       13892   Y694C   T  38639401   C   Non_Hotspot              0.0
# 962       13904   Y774C   T  38629006   C  Mild_Hotspot              0.0
# 963       13905   Y774D   A  38629007   C  Mild_Hotspot              0.0
# 964       13928    Y87C   T  38674539   C       Hotspot              1.0
#
#      Function PREDICTION_provean  provean_score  ...  other gnomAD  \
# ...

# %%
list(scn5a_brs1_cor_data)
# Out:
# ['Unnamed: 0',
#  'var',
#  'ref',
#  'pos',
#  'alt',
#  'Structure_BrS',
#  'brs1_penetrance',
#  'Function',
#  'PREDICTION_provean',
#  'provean_score',
#  'eaRate',
#  'prediction',
#  'pph2_prob',
#  'blastpssm',
#  'pamscore',
#  'SIFT_score',
#  'PREDICTION_sift',
#  'Structure_LQT',
#  'lqt3_penetrance',
#  'resnum',
#  'REVEL',
#  'lqt3',
#  'brs1',
#  'unaff',
#  'other',
#  'gnomAD',
#  'gnomAD_seq',
#  'total_carriers',
#  'unaff_gnomad',
#  'weight',
#  'brs1_penetranceBayesian_initial',
#  'brs1_penetranceBayesian',
#  'brs1_dist',
#  'brs1_dist_weight']

# %%
scn5a_brs1_seq_data = pd.read_csv('csv_data/scn5a_brs1_seq_data.csv')

# %%
scn5a_brs1_seq_data
# Out:
#      Unnamed: 0     var ref       pos alt Structure_BrS  brs1_penetrance  \
# 0             4  A1006S   C  38622634   A   Non_Hotspot              0.0
# 1            11  A1050T   C  38622502   T   Non_Hotspot              0.0
# 2            13  A1052D   G  38622495   T   Non_Hotspot              0.0
# 3            29  A1088T   C  38620953   T   Non_Hotspot              0.0
# 4            30  A1088V   G  38620952   A   Non_Hotspot              0.0
# ..          ...     ...  ..       ...  ..           ...              ...
# 960       13886    Y68C   T  38674596   C   Non_Hotspot              0.0
# 961       13892   Y694C   T  38639401   C   Non_Hotspot              0.0
# 962       13904   Y774C   T  38629006   C  Mild_Hotspot              0.0
# 963       13905   Y774D   A  38629007   C  Mild_Hotspot              0.0
# 964       13928    Y87C   T  38674539   C       Hotspot              1.0
#
#      Function PREDICTION_provean  provean_score  ...  other gnomAD  \
# ...

# %%
list(scn5a_brs1_seq_data)
# Out:
# ['Unnamed: 0',
#  'var',
#  'ref',
#  'pos',
#  'alt',
#  'Structure_BrS',
#  'brs1_penetrance',
#  'Function',
#  'PREDICTION_provean',
#  'provean_score',
#  'eaRate',
#  'prediction',
#  'pph2_prob',
#  'blastpssm',
#  'pamscore',
#  'SIFT_score',
#  'PREDICTION_sift',
#  'Structure_LQT',
#  'lqt3_penetrance',
#  'resnum',
#  'REVEL',
#  'lqt3',
#  'brs1',
#  'unaff',
#  'other',
#  'gnomAD',
#  'gnomAD_seq',
#  'total_carriers',
#  'unaff_gnomad',
#  'weight',
#  'brs1_penetranceBayesian_initial',
#  'brs1_penetranceBayesian',
#  'brs1_dist',
#  'brs1_dist_weight']

# %%
scn5a_brs1_cor_data.compare(scn5a_brs1_seq_data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# scn5a_brs1_seq_data =?= scn5a_brs1_cor_data 
scn5a_brs1_seq_data.compare(scn5a_brs1_cor_data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### seq_data

# %%
seq_data_funcdist2_new = pd.read_csv('csv_data/seq_data_funcdist2_new.csv')

# %%
seq_data_funcdist2_new
# Out:
#      Unnamed: 0     var isoform  mut_type  resnum  lqt2  unaff  \
# 0             1  A1017S       A  missense    1017     0      1
# 1             2  A1017T       A  missense    1017     0      2
# 2             3  A1017V       A  missense    1017     0      3
# 3             4  A1058E       A  missense    1058     0      1
# 4             5  A1058T       A  missense    1058     0      2
# ..          ...     ...     ...       ...     ...   ...    ...
# 895         898   Y611D       A  missense     611     1      0
# 896         899   Y616S       A  missense     616     3      0
# 897         900   Y812S       A  missense     812     0      1
# 898         901    Y99N       A  missense      99     1      0
# 899         902    Y99S       A  missense      99     2      0
#
#      total_carriers  gnomAD  gnomAD_seq  ...    Structure  Function  p_mean_w  \
# 0                 1     1.0    156338.0  ...  Non_Hotspot       NaN  0.054923
# ...

# %%
list(seq_data_funcdist2_new)
# Out:
# ['Unnamed: 0',
#  'var',
#  'isoform',
#  'mut_type',
#  'resnum',
#  'lqt2',
#  'unaff',
#  'total_carriers',
#  'gnomAD',
#  'gnomAD_seq',
#  'weight',
#  'penetrance_lqt2',
#  'lqt2_penetranceBayesian_initial',
#  'lqt2_penetranceBayesian',
#  'pph2_prob',
#  'blast_pssm',
#  'provean_score',
#  'pamscore',
#  'aasimilaritymat',
#  'revel_score',
#  'hm_ssPeak',
#  'hm_tailPeak',
#  'hm_vhalfact',
#  'hm_vhalfinact',
#  'hm_recovfrominact',
#  'hm_taudeact_fast',
#  'ht_ssPeak',
#  'ht_tailPeak',
#  'ht_vhalfact',
#  'ht_vhalfinact',
#  'ht_recovfrominact',
#  'ht_taudeact_fast',
#  'lqt2_dist',
#  'lqt2_dist_weight',
#  'Structure',
#  'Function',
#  'p_mean_w',
#  'prior_mean_w',
#  'prior_mean',
#  'alpha',
#  'beta',
#  'lqt2_patho',
#  'p_mean_prior',
#  'Mean']

# %%
seq_observed_data_new = pd.read_csv('csv_data/seq_observed_data_new.csv')

# %%
seq_observed_data_new
# Out:
#      Unnamed: 0    var isoform  mut_type  resnum  lqt2  unaff  total_carriers  \
# 0            32   A32T       A  missense      32     1      0               1
# 1            33   A34T       A  missense      34     0      1               1
# 2            35  A382T       A  missense     382     1      1               2
# 3            36  A422T       A  missense     422     3      0               3
# 4            37  A429P       A  missense     429     2      1               3
# ..          ...    ...     ...       ...     ...   ...    ...             ...
# 520         898  Y611D       A  missense     611     1      0               1
# 521         899  Y616S       A  missense     616     3      0               3
# 522         900  Y812S       A  missense     812     0      1               1
# 523         901   Y99N       A  missense      99     1      0               1
# 524         902   Y99S       A  missense      99     2      0               2
#
# ...

# %%
list(seq_observed_data_new)
# Out:
# ['Unnamed: 0',
#  'var',
#  'isoform',
#  'mut_type',
#  'resnum',
#  'lqt2',
#  'unaff',
#  'total_carriers',
#  'gnomAD',
#  'gnomAD_seq',
#  'weight',
#  'penetrance_lqt2',
#  'lqt2_penetranceBayesian_initial',
#  'lqt2_penetranceBayesian',
#  'pph2_prob',
#  'blast_pssm',
#  'provean_score',
#  'pamscore',
#  'aasimilaritymat',
#  'revel_score',
#  'hm_ssPeak',
#  'hm_tailPeak',
#  'hm_vhalfact',
#  'hm_vhalfinact',
#  'hm_recovfrominact',
#  'hm_taudeact_fast',
#  'ht_ssPeak',
#  'ht_tailPeak',
#  'ht_vhalfact',
#  'ht_vhalfinact',
#  'ht_recovfrominact',
#  'ht_taudeact_fast',
#  'lqt2_dist',
#  'lqt2_dist_weight',
#  'Structure',
#  'Function',
#  'p_mean_w',
#  'prior_mean_w',
#  'prior_mean',
#  'alpha',
#  'beta',
#  'lqt2_patho',
#  'p_mean_prior',
#  'Mean']

# %%
seq_observed_data_new.compare(seq_data_funcdist2_new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [62], in <module>
#       1 # seq_observed_data_new =?=
# ----> 2 seq_observed_data_new.compare(seq_data_funcdist2_new)
#
# File c:\python38\lib\site-packages\pandas\core\frame.py:7187, in DataFrame.compare(self, other, align_axis, keep_shape, keep_equal)
#    7074 @doc(
#    7075     _shared_docs["compare"],
#    7076     """
#    (...)
#    7185     keep_equal: bool = False,
#    7186 ) -> DataFrame:
# -> 7187     return super().compare(
#    7188         other=other,
#    7189         align_axis=align_axis,
#    7190         keep_shape=keep_shape,
#    7191         keep_equal=keep_equal,
#    7192     )
#
# File c:\python38\lib\site-packages\pandas\core\generic.py:8646, in NDFrame.compare(self, other, align_axis, keep_shape, keep_equal)
#    8641     cls_self, cls_other = type(self).__name__, type(other).__name__
# ...

# %% [markdown]
# ### In The Data Folder

# %%
herg_correlation_analysis = pd.read_csv('csv_data/Covariates/herg-correlation-analysis.csv')

# %%
herg_correlation_analysis
# Out:
#         resA  resB chains   type     max   median    mean  distance
# 0          1     1     BC  right  0.0516  0.01695  0.0204      40.0
# 1          1     2     DD  intra  0.5183  0.03140  0.1449       3.9
# 2          1     3     DD  intra  0.3910  0.03400  0.1069       5.7
# 3          1     4     BB  intra  0.2733  0.03255  0.0837      10.2
# 4          1     5     DD  intra  0.2727  0.03200  0.0714       9.4
# ...      ...   ...    ...    ...     ...      ...     ...       ...
# 388124   863   859     CC  intra  0.3262  0.03200  0.0924      12.5
# 388125   863   860     CC  intra  0.3266  0.02580  0.0927       9.5
# 388126   863   861     CC  intra  0.5123  0.03205  0.1406       5.8
# 388127   863   862     CC  intra  0.5118  0.03395  0.1430       3.9
# 388128   863   863     CD  right  0.0729  0.00910  0.0217      41.7
#
# [388129 rows x 8 columns]

# %%
list(herg_correlation_analysis)
# Out:
# ['resA', 'resB', 'chains', 'type', 'max', 'median', 'mean', 'distance']

# %%
KCNH2_clinical_data = pd.read_csv('csv_data/Covariates/KCNH2_clinical_data.csv')

# %%
KCNH2_clinical_data
# Out:
#        Unnamed: 0       var isoform  mut_type  resnum  lqt2  unaff  \
# 0               1  A1017fsX       A  nonsense  1017.0     1      0
# 1               2    A1017S       A  missense  1017.0     0      1
# 2               3    A1017T       A  missense  1017.0     0      2
# 3               4    A1017V       A  missense  1017.0     0      3
# 4               5    A1058E       A  missense  1058.0     0      1
# ...           ...       ...     ...       ...     ...   ...    ...
# 13682       14079     T337N       A  missense     NaN     0      0
# 13683       14080    Y1078H       A  missense  1078.0     0      0
# 13684       14081    Y1078H       A  missense     NaN     0      0
# 13685       14082     T675R       A  missense   675.0     0      0
# 13686       14083     T675R       A  missense     NaN     0      0
#
#        total_carriers  gnomAD  gnomAD_seq  ...  ht_taudeact_fast  lqt2_dist  \
# 0                   1     0.0         NaN  ...               NaN        NaN
# ...

# %%
list(KCNH2_clinical_data)
# Out:
# ['Unnamed: 0',
#  'var',
#  'isoform',
#  'mut_type',
#  'resnum',
#  'lqt2',
#  'unaff',
#  'total_carriers',
#  'gnomAD',
#  'gnomAD_seq',
#  'weight',
#  'penetrance_lqt2',
#  'lqt2_penetranceBayesian_initial',
#  'lqt2_penetranceBayesian',
#  'pph2_prob',
#  'blast_pssm',
#  'provean_score',
#  'pamscore',
#  'aasimilaritymat',
#  'revel_score',
#  'cardiacboost',
#  'hm_ssPeak',
#  'hm_tailPeak',
#  'hm_vhalfact',
#  'hm_vhalfinact',
#  'hm_recovfrominact',
#  'hm_taudeact_fast',
#  'ht_ssPeak',
#  'ht_tailPeak',
#  'ht_vhalfact',
#  'ht_vhalfinact',
#  'ht_recovfrominact',
#  'ht_taudeact_fast',
#  'lqt2_dist',
#  'lqt2_dist_weight',
#  'Structure',
#  'Function',
#  'p_mean_w',
#  'prior_mean_w',
#  'prior_mean',
#  'alpha',
#  'beta']

# %%
all_lqt2_data_trunc.compare(KCNH2_clinical_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [73], in <module>
# ----> 1 all_lqt2_data_trunc.compare(KCNH2_clinical_data)
#
# File c:\python38\lib\site-packages\pandas\core\frame.py:7187, in DataFrame.compare(self, other, align_axis, keep_shape, keep_equal)
#    7074 @doc(
#    7075     _shared_docs["compare"],
#    7076     """
#    (...)
#    7185     keep_equal: bool = False,
#    7186 ) -> DataFrame:
# -> 7187     return super().compare(
#    7188         other=other,
#    7189         align_axis=align_axis,
#    7190         keep_shape=keep_shape,
#    7191         keep_equal=keep_equal,
#    7192     )
#
# File c:\python38\lib\site-packages\pandas\core\generic.py:8646, in NDFrame.compare(self, other, align_axis, keep_shape, keep_equal)
#    8641     cls_self, cls_other = type(self).__name__, type(other).__name__
#    8642     raise TypeError(
# ...

# %%
scn5a_distances_final = pd.read_csv('csv_data/Covariates/structure_files/scn5a_distances_final.csv')

# %%
scn5a_distances_final
# Out:
#         resnum  neighbor  distance
# 0            1         1  0.000000
# 1            1         2  3.800000
# 2            1         3  5.374012
# 3            1         4  6.581793
# 4            1         5  7.600000
# ...        ...       ...       ...
# 198335    2016      2012  7.600000
# 198336    2016      2013  6.581793
# 198337    2016      2014  5.374012
# 198338    2016      2015  3.800000
# 198339    2016      2016  0.000000
#
# [198340 rows x 3 columns]

# %%
list(scn5a_distances_final)
# Out:
# ['resnum', 'neighbor', 'distance']

# %%
# !pip install openpyxl
# Out:
# ...
#      -------------------------------------- 242.1/242.1 kB 3.7 MB/s eta 0:00:00
# ...

# %%
herg_S2 = pd.read_excel('csv_data/Covariates/structure_files/herg-S2.xlsx')

# %%
herg_S2
# Out:
#      Vector#  Residue#   ChainA   CHainB   ChainC   ChainD      Mean    StdDev
# 0          1         3  0.47820  0.74866  0.66552  0.78719  0.669893  0.137511
# 1          2         4  0.77802  0.71223  0.60695  0.81575  0.728237  0.091476
# 2          3         5  0.83236  0.84462  0.78317  0.84175  0.825475  0.028685
# 3          4         6  0.75369  0.74986  0.64777  0.20916  0.590120  0.258667
# 4          5         7  0.56181  0.47394  0.65439  0.53747  0.556902  0.074807
# ..       ...       ...      ...      ...      ...      ...       ...       ...
# 590      591       619  0.81204  0.85780  0.86092  0.86145  0.848052  0.024062
# 591      592       620  0.84904  0.90171  0.89652  0.90089  0.887040  0.025436
# 592      593       621  0.78952  0.86137  0.86226  0.86183  0.843745  0.036152
# 593      594       622  0.79948  0.89533  0.89118  0.88788  0.868467  0.046093
# 594      595       623  0.84565  0.88307  0.88591  0.88493  0.874890  0.019529
#
# [595 rows x 8 columns]

# %%
list(herg_S2)
# Out:
# ['Vector#',
#  'Residue#',
#  'ChainA',
#  'CHainB',
#  'ChainC',
#  'ChainD',
#  'Mean',
#  'StdDev']
