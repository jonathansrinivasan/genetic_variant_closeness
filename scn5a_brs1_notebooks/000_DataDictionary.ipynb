# %% [markdown]
# # Data Dictionary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../csv_data/scn5a_brs1_all_data.csv')

# %%
df
# Out:
#       Unnamed: 0     var ref       pos alt Structure_BrS  brs1_penetrance  \
# 0              4  A1006S   C  38622634   A   Non_Hotspot              0.0
# 1             11  A1050T   C  38622502   T   Non_Hotspot              0.0
# 2             13  A1052D   G  38622495   T   Non_Hotspot              0.0
# 3             29  A1088T   C  38620953   T   Non_Hotspot              0.0
# 4             30  A1088V   G  38620952   A   Non_Hotspot              0.0
# ...          ...     ...  ..       ...  ..           ...              ...
# 1369       13886    Y68C   T  38674596   C   Non_Hotspot              0.0
# 1370       13892   Y694C   T  38639401   C   Non_Hotspot              0.0
# 1371       13904   Y774C   T  38629006   C  Mild_Hotspot              0.0
# 1372       13905   Y774D   A  38629007   C  Mild_Hotspot              0.0
# 1373       13928    Y87C   T  38674539   C       Hotspot              1.0
#
#       Function PREDICTION_provean  provean_score  ...  other gnomAD  \
# ...

# %%
list(df)
# Out:
# ['Unnamed: 0',
#  'var',
#  'ref',
#  'pos',
#  'alt',
#  'Structure_BrS',
#  'brs1_penetrance',
#  'Function',
#  'PREDICTION_provean',
#  'provean_score',
#  'eaRate',
#  'prediction',
#  'pph2_prob',
#  'blastpssm',
#  'pamscore',
#  'SIFT_score',
#  'PREDICTION_sift',
#  'Structure_LQT',
#  'lqt3_penetrance',
#  'resnum',
#  'REVEL',
#  'lqt3',
#  'brs1',
#  'unaff',
#  'other',
#  'gnomAD',
#  'gnomAD_seq',
#  'total_carriers',
#  'unaff_gnomad',
#  'weight',
#  'brs1_penetranceBayesian_initial',
#  'brs1_penetranceBayesian',
#  'brs1_dist',
#  'brs1_dist_weight']

# %%
df['lqt3_penetrance'].unique()
# Out:
# array([3.50856060e-02, 5.45535580e-02, 4.63539020e-02, 1.12626920e-02,
#        2.86209420e-02, 3.84089550e-02, 6.67823950e-02, 2.82230800e-02,
#        8.13447400e-03, 1.42474657e-01, 1.19418667e-01, 5.01516630e-02,
#        1.75060110e-02, 4.92863100e-02, 2.15226020e-02, 6.12352800e-02,
#        2.76079390e-02, 1.12937650e-02, 1.69057820e-02, 7.65210820e-02,
#        3.05470880e-02, 8.72653800e-03, 2.87951560e-02, 6.57198000e-03,
#        3.18522370e-02, 2.73023330e-02, 3.16114810e-02, 3.29993260e-02,
#        1.38807810e-02, 6.03542410e-02, 3.05819370e-02, 6.24070850e-02,
#        5.46409190e-02, 5.94458975e-01, 4.32460330e-02, 5.59645500e-03,
#        1.92162840e-02, 9.27140800e-02, 6.73708340e-02, 5.13514150e-02,
#        1.90299255e-01, 9.19466020e-02, 5.24143890e-02, 1.05067391e-01,
#        2.89760628e-01, 4.01203723e-01, 3.90697900e-01, 1.27232170e-01,
#        2.95074382e-01, 3.54623182e-01, 3.86940900e-02, 3.19565340e-02,
# ...

# %%
df['brs1_penetrance'].unique()
# Out:
# array([0.00000000e+00, 1.42857143e-01, 1.00000000e+00, 2.00000000e-01,
#        1.11111111e-01, 6.66666667e-01, 6.82593857e-04, 7.50000000e-01,
#        6.25000000e-01, 4.16666667e-02, 8.00000000e-01, 3.33333333e-01,
#        2.50000000e-01, 4.44444444e-01, 6.00000000e-01, 5.00000000e-01,
#        5.41666667e-01, 8.12500000e-01, 9.09090909e-01, 4.00000000e-01,
#        8.18181818e-01, 3.75000000e-01, 5.55555556e-02, 1.25000000e-01,
#        9.00000000e-01, 8.46153846e-01, 5.26315789e-02, 1.00000000e-01,
#        7.14285714e-01, 1.17647059e-01, 6.25000000e-02, 3.57142857e-02,
#        1.66666667e-01, 1.29870130e-02, 6.66666667e-02, 1.11153455e-04,
#        5.71428571e-01, 7.24637681e-03, 8.33333333e-02, 9.09090909e-02,
#        8.28729282e-02, 2.02020202e-02, 5.88235294e-02, 3.70370370e-02,
#        5.55555556e-01, 3.94736842e-02, 4.54545455e-01, 4.00000000e-02,
#        6.22641509e-01, 4.66666667e-01, 2.77777778e-03, 3.00000000e-01,
# ...

# %%
df['PREDICTION_sift'].unique()
# Out:
# array(['Tolerated', 'Damaging', nan], dtype=object)

# %%
df.dtypes
# Out:
# Unnamed: 0                           int64
# var                                 object
# ref                                 object
# pos                                  int64
# alt                                 object
# Structure_BrS                       object
# brs1_penetrance                    float64
# Function                            object
# PREDICTION_provean                  object
# provean_score                      float64
# eaRate                             float64
# prediction                          object
# pph2_prob                          float64
# blastpssm                          float64
# pamscore                           float64
# SIFT_score                         float64
# PREDICTION_sift                     object
# Structure_LQT                       object
# lqt3_penetrance                    float64
# resnum                               int64
# REVEL                              float64
# lqt3                                 int64
# ...

# %%
na_counts = df.isna().sum()

# sort the columns by the number of NaN values in descending order
na_counts = na_counts.sort_values(ascending=False)

# print the result
print(na_counts)
# Out:
# Function                           1187
# gnomAD_seq                          540
# PREDICTION_sift                     440
# SIFT_score                          440
# PREDICTION_provean                  440
# provean_score                       440
# prediction                          433
# pph2_prob                           433
# pamscore                            427
# blastpssm                           427
# eaRate                              427
# Structure_LQT                       410
# Structure_BrS                       410
# alt                                 188
# ref                                 188
# other                                 0
# brs1_penetranceBayesian               0
# brs1_dist                             0
# brs1_penetranceBayesian_initial       0
# weight                                0
# unaff_gnomad                          0
# total_carriers                        0
# gnomAD                                0
# ...

# %%
df = pd.read_csv('../csv_data/scn5a_brs1_cor_data.csv')

# %%
df
# Out:
#      Unnamed: 0     var ref       pos alt Structure_BrS  brs1_penetrance  \
# 0             4  A1006S   C  38622634   A   Non_Hotspot              0.0
# 1            11  A1050T   C  38622502   T   Non_Hotspot              0.0
# 2            13  A1052D   G  38622495   T   Non_Hotspot              0.0
# 3            29  A1088T   C  38620953   T   Non_Hotspot              0.0
# 4            30  A1088V   G  38620952   A   Non_Hotspot              0.0
# ..          ...     ...  ..       ...  ..           ...              ...
# 960       13886    Y68C   T  38674596   C   Non_Hotspot              0.0
# 961       13892   Y694C   T  38639401   C   Non_Hotspot              0.0
# 962       13904   Y774C   T  38629006   C  Mild_Hotspot              0.0
# 963       13905   Y774D   A  38629007   C  Mild_Hotspot              0.0
# 964       13928    Y87C   T  38674539   C       Hotspot              1.0
#
#      Function PREDICTION_provean  provean_score  ...  other gnomAD  \
# ...

# %%
list(df)
# Out:
# ['Unnamed: 0',
#  'var',
#  'ref',
#  'pos',
#  'alt',
#  'Structure_BrS',
#  'brs1_penetrance',
#  'Function',
#  'PREDICTION_provean',
#  'provean_score',
#  'eaRate',
#  'prediction',
#  'pph2_prob',
#  'blastpssm',
#  'pamscore',
#  'SIFT_score',
#  'PREDICTION_sift',
#  'Structure_LQT',
#  'lqt3_penetrance',
#  'resnum',
#  'REVEL',
#  'lqt3',
#  'brs1',
#  'unaff',
#  'other',
#  'gnomAD',
#  'gnomAD_seq',
#  'total_carriers',
#  'unaff_gnomad',
#  'weight',
#  'brs1_penetranceBayesian_initial',
#  'brs1_penetranceBayesian',
#  'brs1_dist',
#  'brs1_dist_weight']

# %%
df = pd.read_csv('../csv_data/scn5a_brs1_seq_data.csv')

# %%
df
# Out:
#      Unnamed: 0     var ref       pos alt Structure_BrS  brs1_penetrance  \
# 0             4  A1006S   C  38622634   A   Non_Hotspot              0.0
# 1            11  A1050T   C  38622502   T   Non_Hotspot              0.0
# 2            13  A1052D   G  38622495   T   Non_Hotspot              0.0
# 3            29  A1088T   C  38620953   T   Non_Hotspot              0.0
# 4            30  A1088V   G  38620952   A   Non_Hotspot              0.0
# ..          ...     ...  ..       ...  ..           ...              ...
# 960       13886    Y68C   T  38674596   C   Non_Hotspot              0.0
# 961       13892   Y694C   T  38639401   C   Non_Hotspot              0.0
# 962       13904   Y774C   T  38629006   C  Mild_Hotspot              0.0
# 963       13905   Y774D   A  38629007   C  Mild_Hotspot              0.0
# 964       13928    Y87C   T  38674539   C       Hotspot              1.0
#
#      Function PREDICTION_provean  provean_score  ...  other gnomAD  \
# ...

# %%
list(df)
# Out:
# ['Unnamed: 0',
#  'var',
#  'ref',
#  'pos',
#  'alt',
#  'Structure_BrS',
#  'brs1_penetrance',
#  'Function',
#  'PREDICTION_provean',
#  'provean_score',
#  'eaRate',
#  'prediction',
#  'pph2_prob',
#  'blastpssm',
#  'pamscore',
#  'SIFT_score',
#  'PREDICTION_sift',
#  'Structure_LQT',
#  'lqt3_penetrance',
#  'resnum',
#  'REVEL',
#  'lqt3',
#  'brs1',
#  'unaff',
#  'other',
#  'gnomAD',
#  'gnomAD_seq',
#  'total_carriers',
#  'unaff_gnomad',
#  'weight',
#  'brs1_penetranceBayesian_initial',
#  'brs1_penetranceBayesian',
#  'brs1_dist',
#  'brs1_dist_weight']
